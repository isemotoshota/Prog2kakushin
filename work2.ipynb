# %% [markdown]
# <a href="https://colab.research.google.com/github/isemotoshota/Prog2kakushin/blob/main/work2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 以下のコードを先に読み込んでください

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ドラえもんを描画する

# %%
x1 = 300
y1 = 300
a = 0
b = 300
r = np.sqrt((a-x1)**2+(b-y1)**2)
x = np.arange(a-r,a+r+1)
y = np.sqrt(r**2-(x-a)**2)+b
yy = -y+2*b
x2 = x1*5/6
y2 = y1*5/6
a2 = a*5/6
b2 = b*5/6
r2 = np.sqrt((a2-x2)**2+(b2-y2)**2)
X = np.arange(a2-r2,a2+r2+1)
Y = np.sqrt(r2**2-(X-a2)**2)+b2
YY = -Y+2*b2
xi = 0
yi = 400
ai = 0
bi = 350
ri = np.sqrt((ai-xi)**2+(bi-yi)**2)
Xi = np.arange(ai-ri,ai+ri+1)
Yi = np.sqrt(ri**2-(Xi-ai)**2)+bi
YYi = -Yi+2*bi
line = [[0,0],[100,300]]
xm = 0
ym = 100
am = 0
bm = 270
rm = np.sqrt((am-xm)**2+(bm-ym)**2)
Xm = np.arange(am-rm,am+rm+1)
Ym = np.sqrt(rm**2-(Xm-am)**2)+bm
YYm = -Ym+2*bm
n1 = [[100,300],[380,450]]
n2 = [[-100,-300],[380,450]]
n3 = [[100,330],[350,350]]
n4 = [[-100,-330],[350,350]]
n5 = [[100,300],[320,250]]
n6 = [[-100,-300],[320,250]]
d1 = 50
e1 = 70
theta = np.linspace(0,2*np.pi,129)
xe1 = d1*np.cos(theta)+50
ye1 = e1*np.sin(theta)+500
xe2 = d1*np.cos(theta)-50
ye2 = e1*np.sin(theta)+500
d2 = 30
e2 = 50
xE1 = d2*np.cos(theta)+30
yE1 = e2*np.sin(theta)+500
xE2 = d2*np.cos(theta)-30
yE2 = e2*np.sin(theta)+500
plt.plot(x,y,color='b')
plt.plot(x,yy,color='b')
plt.plot(X,Y,color='b')
plt.plot(X,YY,color='b')
plt.plot(Xi,Yi,color='r')
plt.plot(Xi,YYi,color='r')
plt.plot(line[0],line[1],color='k')
plt.plot(Xm,YYm,color='k')
plt.plot(n1[0],n1[1],color='k')
plt.plot(n2[0],n2[1],color='k')
plt.plot(n3[0],n3[1],color='k')
plt.plot(n4[0],n4[1],color='k')
plt.plot(n5[0],n5[1],color='k')
plt.plot(n6[0],n6[1],color='k')
plt.plot(xe1,ye1,color='k')
plt.plot(xe2,ye2,color='k')
plt.plot(xE1,yE1,color='k')
plt.plot(xE2,yE2,color='k')
plt.axis('equal')
plt.grid(color='0.5')
plt.show()
